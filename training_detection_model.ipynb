# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.208  Python-3.9.18 torch-2.1.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3090, 24575MiB)
# Setup complete  (16 CPUs, 63.9 GB RAM, 186.4/250.0 GB disk)

# %%
from ultralytics import YOLO

model = YOLO("yolov8m.pt")

# %%
model.train(data="train_dataset_train/cameras/custom_yaml.yaml", 
            epochs=100,
            batch=32,
            val=True,
            save_period=3
           )
# Out:
# Ultralytics YOLOv8.0.208  Python-3.9.18 torch-2.1.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3090, 24575MiB)
# ...
