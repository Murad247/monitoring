# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.208  Python-3.9.18 torch-2.1.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3090, 24575MiB)
# Setup complete  (16 CPUs, 63.9 GB RAM, 180.3/250.0 GB disk)

# %%
from ultralytics import YOLO
import os
import shutil

model = YOLO("yolov8x-seg.pt")

# %%
model.train(data='train_dataset_train/cameras/train/monitoring.v5i.yolov8/data.yaml", 
            imgsz=1280,
            epochs=150,
            batch=4,
            val=True,
           save_period=1
           )
# Out:
# Ultralytics YOLOv8.0.208  Python-3.9.18 torch-2.1.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3090, 24575MiB)
# ...
